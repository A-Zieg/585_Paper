# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
from finance_byu.rolling import roll_sum
from finance_byu.summarize import summary
from finance_byu.regtables import Regtable

# %% [markdown]
# # Initiations:

# %%
pd.options.display.max_rows = 100

# Read in the monthly CRSP data, clean, and set up features
stk = pd.read_csv('crsp_monthly.csv', parse_dates=['caldt'])
stk['mdt'] = stk['caldt'].values.astype('datetime64[M]')

stk['prc'] = stk['prc'].abs()
stk['me']  = stk.eval("prc*shr/1000.0").where(stk.eval("prc*shr > 1e-6")) 

stk['prclag'] = stk.groupby('permno')['prc'].shift()
stk['melag'] = stk.groupby('permno')['me'].shift()
stk
# Out:
#          permno      caldt     cusip ticker  shrcd  excd  siccd        prc  \
# 0         10000 1986-01-31  68391610  OMFGA     10     3   3990    4.37500
# 1         10000 1986-02-28  68391610  OMFGA     10     3   3990    3.25000
# 2         10000 1986-03-31  68391610  OMFGA     10     3   3990    4.43750
# 3         10000 1986-04-30  68391610  OMFGA     10     3   3990    4.00000
# 4         10000 1986-05-30  68391610  OMFGA     10     3   3990    3.10938
# ...         ...        ...       ...    ...    ...   ...    ...        ...
# 5004038   93436 2024-08-30  88160R10   TSLA     11     3   9999  214.11000
# 5004039   93436 2024-09-30  88160R10   TSLA     11     3   9999  261.63000
# 5004040   93436 2024-10-31  88160R10   TSLA     11     3   9999  249.85000
# 5004041   93436 2024-11-29  88160R10   TSLA     11     3   9999  345.16000
# 5004042   93436 2024-12-31  88160R10   TSLA     11     3   9999  403.84000
#
#               ret         vol        shr  cumfacshr        mdt            me  \
# 0             NaN      1771.0     3680.0        1.0 1986-01-01  1.610000e+01
# 1       -0.257143       828.0     3680.0        1.0 1986-02-01  1.196000e+01
# 2        0.365385      1078.0     3680.0        1.0 1986-03-01  1.633000e+01
# 3       -0.098592       957.0     3793.0        1.0 1986-04-01  1.517200e+01
# 4       -0.222656      1074.0     3793.0        1.0 1986-05-01  1.179388e+01
# ...           ...         ...        ...        ...        ...           ...
# 5004038 -0.077391  16108400.0  3194640.0        1.0 2024-08-01  6.840044e+05
# 5004039  0.221942  16042100.0  3207000.0        1.0 2024-09-01  8.390474e+05
# 5004040 -0.045025  19014300.0  3210060.0        1.0 2024-10-01  8.020335e+05
# 5004041  0.381469  20821300.0  3210060.0        1.0 2024-11-01  1.107984e+06
# 5004042  0.170008  18946400.0  3210060.0        1.0 2024-12-01  1.296351e+06
#
#            prclag         melag
# 0             NaN           NaN
# 1          4.3750  1.610000e+01
# 2          3.2500  1.196000e+01
# 3          4.4375  1.633000e+01
# 4          4.0000  1.517200e+01
# ...           ...           ...
# 5004038  232.0700  7.413801e+05
# 5004039  214.1100  6.840044e+05
# 5004040  261.6300  8.390474e+05
# 5004041  249.8500  8.020335e+05
# 5004042  345.1600  1.107984e+06
#
# [5004043 rows x 16 columns]

# %%
# Read in the dividends data, clean, and set up features
div = pd.read_csv('dividends_cash.csv', parse_dates=['dclrdt', 'exdt', 'paydt'])
div['mdt'] = div['paydt'].values.astype('datetime64[M]')
div = div[['permno','mdt','divamt']]
div
# Out:
#         permno        mdt  divamt
# 0        10001 1986-03-01   0.095
# 1        10001 1986-06-01   0.105
# 2        10001 1986-09-01   0.105
# 3        10001 1986-12-01   0.105
# 4        10001 1987-03-01   0.105
# ...        ...        ...     ...
# 985382   93429 2023-12-01   0.550
# 985383   93429 2024-03-01   0.550
# 985384   93429 2024-06-01   0.550
# 985385   93429 2024-09-01   0.630
# 985386   93429 2024-12-01   0.630
#
# [985387 rows x 3 columns]

# %%
# Merge the data and lag 1 month to avoid counting the current month
stk = stk.merge(div,on=['permno','mdt'],how='left')
stk['div'] = stk['divamt'].notnull().astype(int)
    
stk['d12'] = (stk.groupby('permno')['div'].rolling(12).sum()
                     .reset_index(drop=True) )
stk['d12'] = stk.groupby('permno')['d12'].shift(1)
stk
# Out:
#          permno      caldt     cusip ticker  shrcd  excd  siccd        prc  \
# 0         10000 1986-01-31  68391610  OMFGA     10     3   3990    4.37500
# 1         10000 1986-02-28  68391610  OMFGA     10     3   3990    3.25000
# 2         10000 1986-03-31  68391610  OMFGA     10     3   3990    4.43750
# 3         10000 1986-04-30  68391610  OMFGA     10     3   3990    4.00000
# 4         10000 1986-05-30  68391610  OMFGA     10     3   3990    3.10938
# ...         ...        ...       ...    ...    ...   ...    ...        ...
# 5041301   93436 2024-08-30  88160R10   TSLA     11     3   9999  214.11000
# 5041302   93436 2024-09-30  88160R10   TSLA     11     3   9999  261.63000
# 5041303   93436 2024-10-31  88160R10   TSLA     11     3   9999  249.85000
# 5041304   93436 2024-11-29  88160R10   TSLA     11     3   9999  345.16000
# 5041305   93436 2024-12-31  88160R10   TSLA     11     3   9999  403.84000
#
#               ret         vol        shr  cumfacshr        mdt            me  \
# 0             NaN      1771.0     3680.0        1.0 1986-01-01  1.610000e+01
# 1       -0.257143       828.0     3680.0        1.0 1986-02-01  1.196000e+01
# 2        0.365385      1078.0     3680.0        1.0 1986-03-01  1.633000e+01
# 3       -0.098592       957.0     3793.0        1.0 1986-04-01  1.517200e+01
# 4       -0.222656      1074.0     3793.0        1.0 1986-05-01  1.179388e+01
# ...           ...         ...        ...        ...        ...           ...
# 5041301 -0.077391  16108400.0  3194640.0        1.0 2024-08-01  6.840044e+05
# 5041302  0.221942  16042100.0  3207000.0        1.0 2024-09-01  8.390474e+05
# 5041303 -0.045025  19014300.0  3210060.0        1.0 2024-10-01  8.020335e+05
# 5041304  0.381469  20821300.0  3210060.0        1.0 2024-11-01  1.107984e+06
# 5041305  0.170008  18946400.0  3210060.0        1.0 2024-12-01  1.296351e+06
#
#            prclag         melag  divamt  div  d12
# 0             NaN           NaN     NaN    0  NaN
# 1          4.3750  1.610000e+01     NaN    0  NaN
# 2          3.2500  1.196000e+01     NaN    0  NaN
# 3          4.4375  1.633000e+01     NaN    0  NaN
# 4          4.0000  1.517200e+01     NaN    0  NaN
# ...           ...           ...     ...  ...  ...
# 5041301  232.0700  7.413801e+05     NaN    0  0.0
# 5041302  214.1100  6.840044e+05     NaN    0  0.0
# 5041303  261.6300  8.390474e+05     NaN    0  0.0
# 5041304  249.8500  8.020335e+05     NaN    0  0.0
# 5041305  345.1600  1.107984e+06     NaN    0  0.0
#
# [5041306 rows x 19 columns]

# %%
# Calculate any initiations in the last 5 years prior to last year  
stk['div60to13'] = (stk.groupby('permno')['div'].rolling(48,12).sum().reset_index(drop=True))

stk['div60to13'] = stk.groupby('permno')['div60to13'].shift(13)

stk['port'] = stk.eval("d12 > 0 and div60to13 == 0").astype(int) 
    
stk = (stk.query("10 <= shrcd <= 11 and melag == melag and "
                 "prclag > 4.999 and ret == ret").reset_index(drop=True))
stk
# Out:
#          permno      caldt     cusip ticker  shrcd  excd  siccd       prc  \
# 0         10001 1986-02-28  39040610   GFGC     11     3   4920    6.2500
# 1         10001 1986-03-31  39040610   GFGC     11     3   4920    6.3125
# 2         10001 1986-04-30  39040610   GFGC     11     3   4920    6.3750
# 3         10001 1986-05-30  39040610   GFGC     11     3   4920    6.3125
# 4         10001 1986-06-30  39040610   GFGC     11     3   4920    6.1250
# ...         ...        ...       ...    ...    ...   ...    ...       ...
# 2888510   93436 2024-08-30  88160R10   TSLA     11     3   9999  214.1100
# 2888511   93436 2024-09-30  88160R10   TSLA     11     3   9999  261.6300
# 2888512   93436 2024-10-31  88160R10   TSLA     11     3   9999  249.8500
# 2888513   93436 2024-11-29  88160R10   TSLA     11     3   9999  345.1600
# 2888514   93436 2024-12-31  88160R10   TSLA     11     3   9999  403.8400
#
#               ret         vol  ...  cumfacshr        mdt            me  \
# 0        0.020408      1067.0  ...        3.0 1986-02-01  6.156250e+00
# 1        0.025200       335.0  ...        3.0 1986-03-01  6.217812e+00
# 2        0.009901       225.0  ...        3.0 1986-04-01  6.279375e+00
# 3       -0.009804       217.0  ...        3.0 1986-05-01  6.217812e+00
# 4       -0.013069       238.0  ...        3.0 1986-06-01  6.033125e+00
# ...           ...         ...  ...        ...        ...           ...
# 2888510 -0.077391  16108400.0  ...        1.0 2024-08-01  6.840044e+05
# 2888511  0.221942  16042100.0  ...        1.0 2024-09-01  8.390474e+05
# 2888512 -0.045025  19014300.0  ...        1.0 2024-10-01  8.020335e+05
# 2888513  0.381469  20821300.0  ...        1.0 2024-11-01  1.107984e+06
# 2888514  0.170008  18946400.0  ...        1.0 2024-12-01  1.296351e+06
#
#            prclag         melag  divamt  div  d12  div60to13  port
# 0          6.1250  6.033125e+00     NaN    0  NaN        NaN     0
# 1          6.2500  6.156250e+00   0.095    1  NaN        NaN     0
# 2          6.3125  6.217812e+00     NaN    0  NaN        NaN     0
# 3          6.3750  6.279375e+00     NaN    0  NaN        NaN     0
# 4          6.3125  6.217812e+00   0.105    1  NaN        NaN     0
# ...           ...           ...     ...  ...  ...        ...   ...
# 2888510  232.0700  7.413801e+05     NaN    0  0.0        0.0     0
# 2888511  214.1100  6.840044e+05     NaN    0  0.0        0.0     0
# 2888512  261.6300  8.390474e+05     NaN    0  0.0        0.0     0
# 2888513  249.8500  8.020335e+05     NaN    0  0.0        0.0     0
# 2888514  345.1600  1.107984e+06     NaN    0  0.0        0.0     0
#
# [2888515 rows x 21 columns]

# %%
# Restrict data to sample period
stk_64to88 = stk[(stk['caldt'] >= '1964-01-01')&(stk['caldt'] <= '1988-12-31')]

# Count and plot initiations by year to check
init_counts = stk_64to88.groupby(stk_64to88['caldt'].dt.year)['port'].sum()

plt.figure(figsize=(12, 6))
init_counts.plot(kind='bar', color='steelblue')
plt.title('Dividend Initiations by Year', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Number of Initiations', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Calculate the equal weight portfolios
ew = (stk_64to88.groupby(['caldt','port'])['ret'].mean().unstack(level='port')
          .rename('p{:.0f}'.format,axis='columns')*100)    

# Get summary statistics for equal weight and print the results
ew_summ = summary(ew)

print("Equal-Weight Portfolios")
ew_summ.round(3)
# Out:
# Equal-Weight Portfolios
# port        p0       p1
# count  300.000  300.000
# mean     1.199    1.898
# std      5.717    7.545
# tstat    3.634    4.358
# pval     0.000    0.000
# min    -27.279  -28.339
# 25%     -1.860   -2.087
# 50%      1.437    1.764
# 75%      4.797    7.240
# max     20.957   24.186

# %%
# Restrict data to sample period
stk['rme'] = stk['ret']*stk['melag']
stk_64to88 = stk[(stk['caldt'] >= '1964-01-01')&(stk['caldt'] <= '1988-12-31')]

# Get summary statistics for value weight and print the results
vw = ((stk_64to88.groupby(['caldt','port'])['rme'].sum()/
        stk_64to88.groupby(['caldt','port'])['melag'].sum()).unstack(level='port')
        .rename('p{:.0f}'.format,axis='columns')*100)    
vw_summ = summary(vw)
print("Value-Weight Portfolios")
vw_summ.round(3)
# Out:
# Value-Weight Portfolios
# port        p0       p1
# count  300.000  300.000
# mean     0.884    1.429
# std      4.575    8.765
# tstat    3.347    2.824
# pval     0.001    0.005
# min    -22.503  -30.646
# 25%     -1.697   -3.117
# 50%      0.895    1.551
# 75%      4.132    6.379
# max     16.723   32.472

# %%
# Now test the model with the CAPM and Fama French models
names = ew.columns.tolist()
    
# Read factors and ensure date parsing
fac = pd.read_csv("https://diether.org/prephd/14-factors.csv",parse_dates=['caldt'])
fac['caldt'] = fac['caldt'].values.astype('datetime64[M]')  # Match monthly frequency
fac = fac.set_index('caldt')
    
# Ensure ew has a proper datetime index
ew.index = ew.index.values.astype('datetime64[M]')

# Perform the join
ew = ew.join(fac, how='inner')

# Now continue with your analysis
ew[names] = ew[names].sub(ew['rf'], axis=0)
ew['spr'] = ew[names[-1]] - ew['p0']
    
summ = summary(ew[names + ['spr']])        
fm = [smf.ols(f'{y} ~ exmkt + smb + hml + umd', data=ew).fit()
        for y in names + ['spr']]
    
print("Equal-Weight Portfolios")
summ.round(3)
# Out:
# Equal-Weight Portfolios
#             p0       p1      spr
# count  300.000  300.000  300.000
# mean     0.645    1.344    0.699
# std      5.741    7.566    2.964
# tstat    1.945    3.076    4.083
# pval     0.053    0.002    0.000
# min    -27.879  -28.939   -9.143
# 25%     -2.492   -2.563   -0.987
# 50%      1.026    1.230    0.467
# 75%      4.171    6.724    2.450
# max     20.377   23.756   12.224

# %%
# Show the regression results for the models
reg_table = Regtable(fm, sig='coeff')
reg_table.render()
# Out:
#                  p0       p1      spr
# Intercept    -0.019    0.589    0.609
#             (-0.55)   (3.67)   (3.85)
# exmkt         0.955    1.088    0.134
#            (115.46)  (28.93)   (3.60)
# smb           0.809    1.120    0.311
#             (66.18)  (20.13)   (5.67)
# hml           0.106   -0.093   -0.199
#              (7.79)  (-1.50)  (-3.26)
# umd          -0.012    0.033    0.044
#             (-1.21)   (0.75)   (1.03)
# obs             300      300      300
# Rsq            0.99     0.88     0.26

# %% [markdown]
# # Omissions

# %% [markdown]
# Note the logic here is similar to before, but now all we have to do is perform a count on the number of dividend events in the prior period and if it is bigger than the current period (ex quarterly dividends in the last year should imply that the year should have 4 payouts and if there are only 3 in this year) then there was an omission somewhere

# %%
# Calculate dividend omissions
stk['div24to13'] = (stk.groupby('permno')['div'].rolling(12).sum().reset_index(drop=True))
stk['div24to13'] = stk.groupby('permno')['div24to13'].shift(13)

# Create omission flag i.e. div_prev12 > d12
stk['omit'] = stk.eval("div24to13 == 4 and d12 < 4").astype(int)

stk = (stk.query("10 <= shrcd <= 11 and melag == melag and "
                 "prclag > 4.999 and ret == ret").reset_index(drop=True))

# %%
# Restrict data to sample period
stk_64to88 = stk[(stk['caldt'] >= '1964-01-01')&(stk['caldt'] <= '1988-12-31')]

# Count and plot omissions by year to check
omit_counts = stk_64to88.groupby(stk_64to88['caldt'].dt.year)['omit'].sum()

plt.figure(figsize=(12, 6))
omit_counts.plot(kind='bar', color='steelblue')
plt.title('Dividend Omissions by Year', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Number of Omissions', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Equal-weight portfolios for omissions
ew_omit = (stk_64to88.groupby(['caldt','omit'])['ret'].mean().unstack(level='omit')
          .rename('p{:.0f}'.format,axis='columns')*100)

# Print summary statistics
print("\nEqual-Weight Omission Portfolios")
summary(ew_omit).round(3)
# Out:
# Equal-Weight Omission Portfolios
# omit        p0       p1
# count  300.000  300.000
# mean     1.218    0.951
# std      5.725    6.509
# tstat    3.685    2.530
# pval     0.000    0.012
# min    -27.245  -29.553
# 25%     -1.836   -2.569
# 50%      1.450    1.269
# 75%      4.839    4.577
# max     20.888   29.662

# %%
# Restrict data to sample period
stk['rme'] = stk['ret']*stk['melag']
stk_64to88 = stk[(stk['caldt'] >= '1964-01-01')&(stk['caldt'] <= '1988-12-31')]

# Value-weight portfolios for omissions
vw_omit = ((stk_64to88.groupby(['caldt','omit'])['rme'].sum()/
            stk_64to88.groupby(['caldt','omit'])['melag'].sum()).unstack(level='omit')
            .rename('p{:.0f}'.format,axis='columns')*100)

print("\nValue-Weight Omission Portfolios")
summary(vw_omit).round(3)
# Out:
# Value-Weight Omission Portfolios
# omit        p0       p1
# count  300.000  300.000
# mean     0.889    0.798
# std      4.580    6.420
# tstat    3.361    2.152
# pval     0.001    0.032
# min    -22.503  -26.255
# 25%     -1.717   -3.127
# 50%      0.887    0.733
# 75%      4.157    4.807
# max     16.828   33.658

# %%
# Factor model analysis for omissions
ew_omit.index = ew_omit.index.values.astype('datetime64[M]')
ew_omit = ew_omit.join(fac, how='inner')
ew_omit[['p0','p1']] = ew_omit[['p0','p1']].sub(ew_omit['rf'], axis=0)
ew_omit['spr'] = ew_omit['p0'] - ew_omit['p1']

# Run factor regressions
fm_omit = [smf.ols(f'{y} ~ exmkt + smb + hml + umd', data=ew_omit).fit()
          for y in ['p0','p1','spr']]

# Show results
print("\nOmission Portfolios Factor Model Results")
Regtable(fm_omit,sig='coeff').render()
# Out:
# Omission Portfolios Factor Model Results
#                  p0       p1      spr
# Intercept    -0.002   -0.530    0.528
#             (-0.05)  (-3.80)   (4.00)
# exmkt         0.956    0.956    0.000
#            (117.88)  (29.28)   (0.00)
# smb           0.809    1.078   -0.270
#             (67.41)  (22.33)  (-5.90)
# hml           0.101    0.455   -0.354
#              (7.53)   (8.44)  (-6.94)
# umd          -0.007   -0.034    0.026
#             (-0.78)  (-0.89)   (0.74)
# obs             300      300      300
# Rsq            0.99     0.88     0.24

# %% [markdown]
# # Extentions

# %% [markdown]
# We should just extend this by testing out of sample, but also note that because we have done this with tradable securities and not just buy and hold this is already an extention inherently, but to extend further, we should do more out of sample past when they finished testing to.

# %%
# Split sample into subperiods periods
split_date = '2000-01-01'
old = stk[stk['caldt'] < split_date]
modern = stk[stk['caldt'] >= split_date]
# Compare in sample with out of sample
after = stk[stk['caldt'] >= '1989-01-01']
before = stk[stk['caldt'] < '1964-01-01']

periods = [old, modern, before, stk_64to88, after]
names = ['PreY2k', 'Modern', 'Before Sample Period', 'Sample Period', 'After Sample Period']

# %%
# Produce subperiod portfolio summary statistics
def analyze_subperiod(data, name):
    # Initiation analysis
    ew_init = (data.groupby(['caldt','port'])['ret'].mean().unstack()*100)
    # Omission analysis
    ew_omit = (data.groupby(['caldt','omit'])['ret'].mean().unstack()*100)
    
    print(f"\n{name} Period Results")
    print("Initiations:")
    print(summary(ew_init).round(3))
    print("\nOmissions:")
    print(summary(ew_omit).round(3))

# %%
analyze_subperiod(periods[0], names[0])
# Out:
# PreY2k Period Results
# Initiations:
# port         0        1
# count  888.000  867.000
# mean     1.113    1.833
# std      6.623    9.495
# tstat    5.008    5.684
# pval     0.000    0.000
# min    -30.908  -34.871
# 25%     -1.924   -2.185
# 50%      1.607    1.902
# 75%      4.387    6.237
# max     44.215  129.667
#
# Omissions:
# omit         0        1
# count  888.000  864.000
# mean     1.121    0.910
# std      6.502    8.248
# tstat    5.140    3.243
# pval     0.000    0.001
# min    -30.390  -36.329
# 25%     -1.895   -2.712
# 50%      1.584    1.121
# 75%      4.436    4.597
# max     40.224   62.268

# %%
analyze_subperiod(periods[1], names[1])
# Out:
# Modern Period Results
# Initiations:
# port         0        1
# count  300.000  300.000
# mean     0.831    1.053
# std      5.406    5.625
# tstat    2.664    3.244
# pval     0.008    0.001
# min    -21.524  -29.002
# 25%     -2.164   -2.086
# 50%      1.188    1.699
# 75%      4.364    4.214
# max     17.958   26.039
#
# Omissions:
# omit         0        1
# count  300.000  300.000
# mean     0.830    0.692
# std      5.384    7.089
# tstat    2.668    1.691
# pval     0.008    0.092
# min    -21.514  -34.749
# 25%     -2.199   -3.164
# 50%      1.189    1.142
# 75%      4.337    4.808
# max     17.541   26.787

# %%
analyze_subperiod(periods[2], names[2])
# Out:
# Before Sample Period Period Results
# Initiations:
# port         0        1
# count  456.000  435.000
# mean     1.023    1.843
# std      7.651   11.624
# tstat    2.854    3.307
# pval     0.005    0.001
# min    -30.908  -34.871
# 25%     -2.227   -2.957
# 50%      1.607    1.763
# 75%      4.360    6.455
# max     44.215  129.667
#
# Omissions:
# omit         0        1
# count  456.000  432.000
# mean     1.024    0.906
# std      7.443    9.996
# tstat    2.937    1.884
# pval     0.003    0.060
# min    -30.390  -36.329
# 25%     -2.175   -3.495
# 50%      1.599    0.910
# 75%      4.325    4.838
# max     40.224   62.268

# %%
analyze_subperiod(periods[3], names[3])
# Out:
# Sample Period Period Results
# Initiations:
# port         0        1
# count  300.000  300.000
# mean     1.199    1.898
# std      5.717    7.545
# tstat    3.634    4.358
# pval     0.000    0.000
# min    -27.279  -28.339
# 25%     -1.860   -2.087
# 50%      1.437    1.764
# 75%      4.797    7.240
# max     20.957   24.186
#
# Omissions:
# omit         0        1
# count  300.000  300.000
# mean     1.218    0.951
# std      5.725    6.509
# tstat    3.685    2.530
# pval     0.000    0.012
# min    -27.245  -29.553
# 25%     -1.836   -2.569
# 50%      1.450    1.269
# 75%      4.839    4.577
# max     20.888   29.662

# %%
analyze_subperiod(periods[4], names[4])
# Out:
# After Sample Period Period Results
# Initiations:
# port         0        1
# count  432.000  432.000
# mean     0.953    1.236
# std      5.107    5.255
# tstat    3.878    4.889
# pval     0.000    0.000
# min    -21.524  -29.002
# 25%     -1.944   -1.747
# 50%      1.397    1.856
# 75%      4.112    4.275
# max     17.958   26.039
#
# Omissions:
# omit         0        1
# count  432.000  432.000
# mean     0.955    0.735
# std      5.091    6.463
# tstat    3.900    2.362
# pval     0.000    0.019
# min    -21.514  -34.749
# 25%     -1.942   -2.530
# 50%      1.386    1.142
# 75%      4.187    4.371
# max     17.541   26.787

# %%
# Count and Plot subperiod initiations and omissions
def count_plot(data, name, category):
    if category.lower() == 'initiations':
        counts = data.groupby(data['caldt'].dt.year)['port'].sum()
        plt.figure(figsize=(12, 6))
        counts.plot(kind='bar', color='steelblue')
        plt.title(f'Dividend Initiations by Year - {names[i]}', fontsize=14)
        plt.xlabel('Year', fontsize=12)
        plt.ylabel('Number of Initiations', fontsize=12)
        plt.grid(axis='y', linestyle='--', alpha=0.7)
        plt.tight_layout()
        plt.show()
        plt.clf()
    else:
        counts = data.groupby(data['caldt'].dt.year)['omit'].sum()
        plt.figure(figsize=(12, 6))
        counts.plot(kind='bar', color='steelblue')
        plt.title(f'Dividend Omissions by Year - {names[i]}', fontsize=14)
        plt.xlabel('Year', fontsize=12)
        plt.ylabel('Number of Omissions', fontsize=12)
        plt.grid(axis='y', linestyle='--', alpha=0.7)
        plt.tight_layout()
        plt.show()
        plt.clf()

# %%
for i in range(len(periods)):
    count_plot(periods[i], names[i], 'Initiations')
    count_plot(periods[i], names[i], 'Omissions')

# %%
# Test equal weight spread portfolios for each subperiod against Fama-French model
reg = {}
regnames = []

def factor_test(data, name):
    init = (data.groupby(['caldt','port'])['ret'].mean().unstack(level='port')*100) 
    omit = (data.groupby(['caldt','omit'])['ret'].mean().unstack(level='omit')*100)
    init.index = init.index.values.astype('datetime64[M]')
    omit.index = omit.index.values.astype('datetime64[M]')
    init = init.join(fac, how='inner')
    omit = omit.join(fac, how='inner')
    init[[0, 1]] = init[[0, 1]].sub(init['rf'], axis=0)
    omit[[0, 1]] = omit[[0, 1]].sub(init['rf'], axis=0)
    init['spread'] = init[1]-init[0]
    omit['spread'] = omit[0]-omit[1]
    reg[f"{name}_init"] = smf.ols("spread ~ exmkt + smb + hml + umd", data=init).fit()
    reg[f"{name}_omit"] = smf.ols("spread ~ exmkt + smb + hml + umd", data=omit).fit()


for i in range(len(periods)):
    factor_test(periods[i], names[i])
    regnames.append(f"{names[i]} initiations")
    regnames.append(f"{names[i]} omissions")


print("Equal Weight Spread Portfolios")
Regtable(list(reg.values()), regnames,sig='coeff').render()
# Out:
# Equal Weight Spread Portfolios
#           PreY2k initiations PreY2k omissions Modern initiations  \
# Intercept              0.420            0.335              0.176
#                       (2.12)           (3.65)             (1.28)
# exmkt                  0.179           -0.042             -0.022
#                       (4.73)          (-2.40)            (-0.66)
# smb                    0.203           -0.165             -0.159
#                       (3.19)          (-5.62)            (-3.62)
# hml                   -0.043           -0.362              0.319
#                      (-0.70)         (-12.82)             (8.01)
# umd                    0.192            0.107              0.077
#                       (3.89)           (4.68)             (2.63)
# obs                      867              864                297
# Rsq                     0.05             0.36               0.25
#
#           Modern omissions Before Sample Period initiations  \
# Intercept            0.257                            0.401
#                     (1.45)                           (1.09)
# exmkt               -0.078                            0.266
#                    (-1.82)                           (3.87)
# smb                 -0.055                            0.243
#                    (-0.97)                           (2.10)
# hml                 -0.519                           -0.091
#                   (-10.08)                          (-0.81)
# umd                  0.103                            0.294
#                     (2.73)                           (3.49)
# obs                    297                              435
# Rsq                   0.32                             0.06
#
#           Before Sample Period omissions Sample Period initiations  \
# Intercept                          0.216                     0.609
#                                   (1.47)                    (3.85)
# exmkt                             -0.058                     0.134
#                                  (-2.11)                    (3.60)
# smb                               -0.155                     0.311
#                                  (-3.36)                    (5.67)
# hml                               -0.289                    -0.199
#                                  (-6.40)                   (-3.26)
# umd                                0.159                     0.044
#                                   (4.74)                    (1.03)
# obs                                  432                       300
# Rsq                                 0.41                      0.26
#
#           Sample Period omissions After Sample Period initiations  \
# Intercept                   0.528                           0.231
#                            (4.00)                          (2.13)
# exmkt                       0.000                          -0.024
#                            (0.00)                         (-0.93)
# smb                        -0.270                          -0.140
#                           (-5.90)                         (-4.01)
# hml                        -0.354                           0.308
#                           (-6.94)                          (9.00)
# umd                         0.026                           0.067
#                            (0.74)                          (2.75)
# obs                           300                             429
# Rsq                          0.24                            0.23
#
#           After Sample Period omissions
# Intercept                         0.287
#                                  (2.14)
# exmkt                            -0.072
#                                 (-2.25)
# smb                              -0.073
#                                 (-1.69)
# hml                              -0.541
#                                (-12.81)
# umd                               0.093
#                                  (3.09)
# obs                                 429
# Rsq                                0.33
