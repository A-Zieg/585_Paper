# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
from tabulate import tabulate
from finance_byu.rolling import roll_sum
from finance_byu.summarize import summary
from finance_byu.regtables import Regtable

# %% [markdown]
# # Initiations:

# %%
pd.options.display.max_rows = 100

# Read in the monthly CRSP data, clean, and set up features
stk = pd.read_feather('C:/Users/jarem/Downloads/crsp_monthly.ftr')
stk['mdt'] = stk['caldt'].values.astype('datetime64[M]')

stk['prc'] = stk['prc'].abs()
stk['me']  = stk.eval("prc*shr/1000.0").where(stk.eval("prc*shr > 1e-6")) 

stk['prclag'] = stk.groupby('permno')['prc'].shift()
stk['melag'] = stk.groupby('permno')['me'].shift()
stk
# Out:
#          permno      caldt     cusip ticker  shrcd  excd  siccd        prc  \
# 0         10000 1986-01-31  68391610  OMFGA     10     3   3990    4.37500
# 1         10000 1986-02-28  68391610  OMFGA     10     3   3990    3.25000
# 2         10000 1986-03-31  68391610  OMFGA     10     3   3990    4.43750
# 3         10000 1986-04-30  68391610  OMFGA     10     3   3990    4.00000
# 4         10000 1986-05-30  68391610  OMFGA     10     3   3990    3.10938
# ...         ...        ...       ...    ...    ...   ...    ...        ...
# 5004038   93436 2024-08-30  88160R10   TSLA     11     3   9999  214.11000
# 5004039   93436 2024-09-30  88160R10   TSLA     11     3   9999  261.63000
# 5004040   93436 2024-10-31  88160R10   TSLA     11     3   9999  249.85001
# 5004041   93436 2024-11-29  88160R10   TSLA     11     3   9999  345.16000
# 5004042   93436 2024-12-31  88160R10   TSLA     11     3   9999  403.84000
#
#               ret         vol        shr  cumfacshr        mdt            me  \
# 0             NaN      1771.0     3680.0        1.0 1986-01-01  1.610000e+01
# 1       -0.257143       828.0     3680.0        1.0 1986-02-01  1.196000e+01
# 2        0.365385      1078.0     3680.0        1.0 1986-03-01  1.633000e+01
# 3       -0.098592       957.0     3793.0        1.0 1986-04-01  1.517200e+01
# 4       -0.222656      1074.0     3793.0        1.0 1986-05-01  1.179388e+01
# ...           ...         ...        ...        ...        ...           ...
# 5004038 -0.077391  16108365.0  3194640.0        1.0 2024-08-01  6.840044e+05
# 5004039  0.221942  16042065.0  3207000.0        1.0 2024-09-01  8.390474e+05
# 5004040 -0.045025  19014312.0  3210060.0        1.0 2024-10-01  8.020335e+05
# 5004041  0.381469  20821313.0  3210060.0        1.0 2024-11-01  1.107984e+06
# 5004042  0.170008  18946442.0  3210060.0        1.0 2024-12-01  1.296351e+06
#
#             prclag         melag
# 0              NaN           NaN
# 1          4.37500  1.610000e+01
# 2          3.25000  1.196000e+01
# 3          4.43750  1.633000e+01
# 4          4.00000  1.517200e+01
# ...            ...           ...
# 5004038  232.07001  7.413801e+05
# 5004039  214.11000  6.840044e+05
# 5004040  261.63000  8.390474e+05
# 5004041  249.85001  8.020335e+05
# 5004042  345.16000  1.107984e+06
#
# [5004043 rows x 16 columns]

# %%
# Read in the dividends data, clean, and set up features
div = pd.read_csv('C:/Users/jarem/Downloads/dividends_cash.csv',parse_dates=['paydt'])
div['mdt'] = div['paydt'].values.astype('datetime64[M]')
div = div[['permno','mdt','divamt']]
div
# Out:
#         permno        mdt  divamt
# 0        10001 1986-03-01   0.095
# 1        10001 1986-06-01   0.105
# 2        10001 1986-09-01   0.105
# 3        10001 1986-12-01   0.105
# 4        10001 1987-03-01   0.105
# ...        ...        ...     ...
# 985382   93429 2023-12-01   0.550
# 985383   93429 2024-03-01   0.550
# 985384   93429 2024-06-01   0.550
# 985385   93429 2024-09-01   0.630
# 985386   93429 2024-12-01   0.630
#
# [985387 rows x 3 columns]

# %%
# Merge the data and lag 1 month to avoid counting the current month
stk = stk.merge(div,on=['permno','mdt'],how='left')
stk['div'] = stk['divamt'].notnull().astype(int)
    
stk['d12'] = (stk.groupby('permno')['div'].rolling(12).sum()
                     .reset_index(drop=True) )
stk['d12'] = stk.groupby('permno')['d12'].shift(1)
stk
# Out:
#          permno      caldt     cusip ticker  shrcd  excd  siccd        prc  \
# 0         10000 1986-01-31  68391610  OMFGA     10     3   3990    4.37500
# 1         10000 1986-02-28  68391610  OMFGA     10     3   3990    3.25000
# 2         10000 1986-03-31  68391610  OMFGA     10     3   3990    4.43750
# 3         10000 1986-04-30  68391610  OMFGA     10     3   3990    4.00000
# 4         10000 1986-05-30  68391610  OMFGA     10     3   3990    3.10938
# ...         ...        ...       ...    ...    ...   ...    ...        ...
# 5041301   93436 2024-08-30  88160R10   TSLA     11     3   9999  214.11000
# 5041302   93436 2024-09-30  88160R10   TSLA     11     3   9999  261.63000
# 5041303   93436 2024-10-31  88160R10   TSLA     11     3   9999  249.85001
# 5041304   93436 2024-11-29  88160R10   TSLA     11     3   9999  345.16000
# 5041305   93436 2024-12-31  88160R10   TSLA     11     3   9999  403.84000
#
#               ret         vol        shr  cumfacshr        mdt            me  \
# 0             NaN      1771.0     3680.0        1.0 1986-01-01  1.610000e+01
# 1       -0.257143       828.0     3680.0        1.0 1986-02-01  1.196000e+01
# 2        0.365385      1078.0     3680.0        1.0 1986-03-01  1.633000e+01
# 3       -0.098592       957.0     3793.0        1.0 1986-04-01  1.517200e+01
# 4       -0.222656      1074.0     3793.0        1.0 1986-05-01  1.179388e+01
# ...           ...         ...        ...        ...        ...           ...
# 5041301 -0.077391  16108365.0  3194640.0        1.0 2024-08-01  6.840044e+05
# 5041302  0.221942  16042065.0  3207000.0        1.0 2024-09-01  8.390474e+05
# 5041303 -0.045025  19014312.0  3210060.0        1.0 2024-10-01  8.020335e+05
# 5041304  0.381469  20821313.0  3210060.0        1.0 2024-11-01  1.107984e+06
# 5041305  0.170008  18946442.0  3210060.0        1.0 2024-12-01  1.296351e+06
#
#             prclag         melag  divamt  div  d12
# 0              NaN           NaN     NaN    0  NaN
# 1          4.37500  1.610000e+01     NaN    0  NaN
# 2          3.25000  1.196000e+01     NaN    0  NaN
# 3          4.43750  1.633000e+01     NaN    0  NaN
# 4          4.00000  1.517200e+01     NaN    0  NaN
# ...            ...           ...     ...  ...  ...
# 5041301  232.07001  7.413801e+05     NaN    0  0.0
# 5041302  214.11000  6.840044e+05     NaN    0  0.0
# 5041303  261.63000  8.390474e+05     NaN    0  0.0
# 5041304  249.85001  8.020335e+05     NaN    0  0.0
# 5041305  345.16000  1.107984e+06     NaN    0  0.0
#
# [5041306 rows x 19 columns]

# %%
# Calculate any initiations in the last 5 years prior to last year  
stk['div60to13'] = (stk.groupby('permno')['div'].rolling(48,12).sum().reset_index(drop=True))

stk['div60to13'] = stk.groupby('permno')['div60to13'].shift(13)

stk['port'] = stk.eval("d12 > 0 and div60to13 == 0").astype(int) 
    
stk = (stk.query("10 <= shrcd <= 11 and melag == melag and "
                 "prclag > 4.999 and ret == ret").reset_index(drop=True))
stk
# Out:
#          permno      caldt     cusip ticker  shrcd  excd  siccd        prc  \
# 0         10001 1986-02-28  39040610   GFGC     11     3   4920    6.25000
# 1         10001 1986-03-31  39040610   GFGC     11     3   4920    6.31250
# 2         10001 1986-04-30  39040610   GFGC     11     3   4920    6.37500
# 3         10001 1986-05-30  39040610   GFGC     11     3   4920    6.31250
# 4         10001 1986-06-30  39040610   GFGC     11     3   4920    6.12500
# ...         ...        ...       ...    ...    ...   ...    ...        ...
# 2888510   93436 2024-08-30  88160R10   TSLA     11     3   9999  214.11000
# 2888511   93436 2024-09-30  88160R10   TSLA     11     3   9999  261.63000
# 2888512   93436 2024-10-31  88160R10   TSLA     11     3   9999  249.85001
# 2888513   93436 2024-11-29  88160R10   TSLA     11     3   9999  345.16000
# 2888514   93436 2024-12-31  88160R10   TSLA     11     3   9999  403.84000
#
#               ret         vol  ...  cumfacshr        mdt            me  \
# 0        0.020408      1067.0  ...        3.0 1986-02-01  6.156250e+00
# 1        0.025200       335.0  ...        3.0 1986-03-01  6.217812e+00
# 2        0.009901       225.0  ...        3.0 1986-04-01  6.279375e+00
# 3       -0.009804       217.0  ...        3.0 1986-05-01  6.217812e+00
# 4       -0.013069       238.0  ...        3.0 1986-06-01  6.033125e+00
# ...           ...         ...  ...        ...        ...           ...
# 2888510 -0.077391  16108365.0  ...        1.0 2024-08-01  6.840044e+05
# 2888511  0.221942  16042065.0  ...        1.0 2024-09-01  8.390474e+05
# 2888512 -0.045025  19014312.0  ...        1.0 2024-10-01  8.020335e+05
# 2888513  0.381469  20821313.0  ...        1.0 2024-11-01  1.107984e+06
# 2888514  0.170008  18946442.0  ...        1.0 2024-12-01  1.296351e+06
#
#             prclag         melag  divamt  div  d12  div60to13  port
# 0          6.12500  6.033125e+00     NaN    0  NaN        NaN     0
# 1          6.25000  6.156250e+00   0.095    1  NaN        NaN     0
# 2          6.31250  6.217812e+00     NaN    0  NaN        NaN     0
# 3          6.37500  6.279375e+00     NaN    0  NaN        NaN     0
# 4          6.31250  6.217812e+00   0.105    1  NaN        NaN     0
# ...            ...           ...     ...  ...  ...        ...   ...
# 2888510  232.07001  7.413801e+05     NaN    0  0.0        0.0     0
# 2888511  214.11000  6.840044e+05     NaN    0  0.0        0.0     0
# 2888512  261.63000  8.390474e+05     NaN    0  0.0        0.0     0
# 2888513  249.85001  8.020335e+05     NaN    0  0.0        0.0     0
# 2888514  345.16000  1.107984e+06     NaN    0  0.0        0.0     0
#
# [2888515 rows x 21 columns]

# %%
# Count and plot initiations by year to check
init_counts = stk.groupby(stk['caldt'].dt.year)['port'].sum()

plt.figure(figsize=(12, 6))
init_counts.plot(kind='bar', color='steelblue')
plt.title('Dividend Initiations by Year', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Number of Initiations', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Calculate the equal weight portfolios
ew = (stk.groupby(['caldt','port'])['ret'].mean().unstack(level='port')
          .rename('p{:.0f}'.format,axis='columns')*100)    

# Get summary statistics for equal weight and print the results
ew_summ = summary(ew)

print("Equal-Weight Portfolios")
ew_summ.round(3)
# Out:
# Equal-Weight Portfolios
# port         p0        p1
# count  1188.000  1167.000
# mean      1.042     1.632
# std       6.337     8.671
# tstat     5.667     6.431
# pval      0.000     0.000
# min     -30.908   -34.871
# 25%      -1.961    -2.177
# 50%       1.484     1.786
# 75%       4.377     5.445
# max      44.215   129.667

# %%
# Get summary statistics for value weight and print the results
stk['rme'] = stk['ret']*stk['melag']
vw = ((stk.groupby(['caldt','port'])['rme'].sum()/
        stk.groupby(['caldt','port'])['melag'].sum()).unstack(level='port')
        .rename('p{:.0f}'.format,axis='columns')*100)    
vw_summ = summary(vw)
print("Value-Weight Portfolios")
vw_summ.round(3)
# Out:
# Value-Weight Portfolios
# port         p0        p1
# count  1188.000  1167.000
# mean      0.945     1.171
# std       5.237     9.485
# tstat     6.217     4.217
# pval      0.000     0.000
# min     -28.770   -45.220
# 25%      -1.744    -3.046
# 50%       1.344     1.433
# 75%       3.943     5.465
# max      37.899   129.667

# %%
# Now test the model with the CAPM and Fama French models
names = ew.columns.tolist()
    
# Read factors and ensure date parsing
fac = pd.read_csv('C:/Users/jarem/Downloads/14-factors.csv', parse_dates=['caldt'])
fac['caldt'] = fac['caldt'].values.astype('datetime64[M]')  # Match monthly frequency
fac = fac.set_index('caldt')
    
# Ensure ew has a proper datetime index
ew.index = ew.index.values.astype('datetime64[M]')

# Perform the join
ew = ew.join(fac, how='inner')

# Now continue with your analysis
ew[names] = ew[names].sub(ew['rf'], axis=0)
ew['spr'] = ew[names[-1]] - ew['p0']
    
summ = summary(ew[names + ['spr']])        
fm = [smf.ols(f'{y} ~ exmkt + smb + hml + umd', data=ew).fit()
        for y in names + ['spr']]
    
print("Equal-Weight Portfolios")
summ.round(3)
# Out:
# Equal-Weight Portfolios
#              p0        p1       spr
# count  1173.000  1164.000  1164.000
# mean      0.783     1.362     0.588
# std       6.367     8.683     5.101
# tstat     4.212     5.353     3.934
# pval      0.000     0.000     0.000
# min     -30.938   -34.901   -22.313
# 25%      -2.341    -2.476    -1.345
# 50%       1.245     1.577     0.267
# 75%       4.163     5.194     2.063
# max      44.185   129.647   114.228

# %%
# Show the regression results for the models
reg_table = Regtable(fm)
reg_table.render()
# Out:
#                  p0       p1     spr
# Intercept    -0.038    0.307   0.346
#             (-1.38)   (1.96)  (2.27)
# exmkt         0.984    1.119   0.136
#            (178.91)  (35.36)  (4.43)
# smb           0.611    0.687   0.076
#             (69.78)  (13.65)  (1.55)
# hml           0.135    0.221   0.087
#             (16.56)   (4.73)  (1.91)
# umd          -0.013    0.161   0.175
#             (-2.07)   (4.37)  (4.88)
# obs            1173     1164    1164
# Rsq            0.98     0.65    0.03

# %% [markdown]
# # Omissions

# %% [markdown]
# Note the logic here is similar to before, but now all we have to do is perform a count on the number of dividend events in the prior period and if it is bigger than the current period (ex quarterly dividends in the last year should imply that the year should have 4 payouts and if there are only 3 in this year) then there was an omission somewhere

# %%
# Calculate dividend omissions
stk['div24to13'] = (stk.groupby('permno')['div'].rolling(24).sum().reset_index(drop=True))
stk['div24to13'] = stk.groupby('permno')['div24to13'].shift(13)

# Create omission flag i.e. div_prev12 > d12
stk['omit'] = stk.eval("div24to13 == 4 and d12 < 4").astype(int)

stk = (stk.query("10 <= shrcd <= 11 and melag == melag and "
                 "prclag > 4.999 and ret == ret").reset_index(drop=True))

# %%
# Count and plot omissions by year to check
omit_counts = stk.groupby(stk['caldt'].dt.year)['omit'].sum()

plt.figure(figsize=(12, 6))
omit_counts.plot(kind='bar', color='steelblue')
plt.title('Dividend Omissions by Year', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Number of Omissions', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Equal-weight portfolios for omissions
ew_omit = (stk.groupby(['caldt','omit'])['ret'].mean().unstack(level='omit')
          .rename('p{:.0f}'.format,axis='columns')*100)

# Print summary statistics
print("\nEqual-Weight Omission Portfolios")
summary(ew_omit).round(3)
# Out:
# Equal-Weight Omission Portfolios
# omit         p0        p1
# count  1188.000  1154.000
# mean      1.046     1.219
# std       6.340     6.916
# tstat     5.687     5.986
# pval      0.000     0.000
# min     -30.903   -32.673
# 25%      -2.019    -2.126
# 50%       1.471     1.396
# 75%       4.376     4.606
# max      43.669    55.135

# %%
# Value-weight portfolios for omissions
stk['rme'] = stk['ret']*stk['melag']
vw_omit = ((stk.groupby(['caldt','omit'])['rme'].sum()/
            stk.groupby(['caldt','omit'])['melag'].sum()).unstack(level='omit')
            .rename('p{:.0f}'.format,axis='columns')*100)

print("\nValue-Weight Omission Portfolios")
summary(vw_omit).round(3)
# Out:
# Value-Weight Omission Portfolios
# omit         p0        p1
# count  1188.000  1154.000
# mean      0.943     0.956
# std       5.233     7.762
# tstat     6.213     4.184
# pval      0.000     0.000
# min     -28.880   -38.447
# 25%      -1.751    -2.899
# 50%       1.304     1.033
# 75%       3.936     5.176
# max      37.728    58.755

# %%
# Factor model analysis for omissions
ew_omit.index = ew_omit.index.values.astype('datetime64[M]')
ew_omit = ew_omit.join(fac, how='inner')
ew_omit[['p0','p1']] = ew_omit[['p0','p1']].sub(ew_omit['rf'], axis=0)
ew_omit['spr'] = ew_omit['p1'] - ew_omit['p0']

# Run factor regressions
fm_omit = [smf.ols(f'{y} ~ exmkt + smb + hml + umd', data=ew_omit).fit()
          for y in ['p0','p1','spr']]

# Show results
print("\nOmission Portfolios Factor Model Results")
Regtable(fm_omit).render()
# Out:
# Omission Portfolios Factor Model Results
#                  p0       p1      spr
# Intercept    -0.034    0.087    0.121
#             (-1.23)   (1.14)   (1.71)
# exmkt         0.986    0.959   -0.027
#            (177.78)  (61.99)  (-1.89)
# smb           0.611    0.623    0.011
#             (69.23)  (25.36)   (0.51)
# hml           0.130    0.335    0.205
#             (15.92)  (14.71)   (9.77)
# umd          -0.012    0.001    0.013
#             (-1.90)   (0.07)   (0.78)
# obs            1173     1151     1151
# Rsq            0.98     0.87     0.08

# %% [markdown]
# # Extentions

# %% [markdown]
# We should just extend this by testing out of sample, but also note that because we have done this with tradable securities and not just buy and hold this is already an extention inherently, but to extend further, we should do more out of sample past when they finished testing to.

# %%
# For extensions, we can test in different subperiods

# Split sample into early and late periods
split_date = '2000-01-01'
early = stk[stk['caldt'] < split_date]
late = stk[stk['caldt'] >= split_date]

# Repeat analysis for each subperiod
def analyze_subperiod(data, name):
    # Initiation analysis
    ew_init = (data.groupby(['caldt','port'])['ret'].mean().unstack()*100)
    # Omission analysis
    ew_omit = (data.groupby(['caldt','omit'])['ret'].mean().unstack()*100)
    
    print(f"\n{name} Period Results")
    print("Initiations:")
    print(summary(ew_init).round(3))
    print("\nOmissions:")
    print(summary(ew_omit).round(3))

analyze_subperiod(early, "Early")
analyze_subperiod(late, "Late")
# Out:
# Early Period Results
# Initiations:
# port         0        1
# count  888.000  867.000
# mean     1.113    1.833
# std      6.623    9.495
# tstat    5.008    5.684
# pval     0.000    0.000
# min    -30.908  -34.871
# 25%     -1.924   -2.185
# 50%      1.607    1.902
# 75%      4.387    6.237
# max     44.215  129.667
#
# Omissions:
# omit         0        1
# count  888.000  854.000
# mean     1.118    1.263
# std      6.625    7.437
# tstat    5.029    4.964
# pval     0.000    0.000
# min    -30.903  -32.673
# 25%     -1.907   -2.367
# 50%      1.598    1.406
# 75%      4.388    4.777
# max     43.669   55.135
#
# Late Period Results
# Initiations:
# port         0        1
# count  300.000  300.000
# mean     0.831    1.053
# std      5.406    5.625
# tstat    2.664    3.244
# pval     0.008    0.001
# min    -21.524  -29.002
# 25%     -2.164   -2.086
# 50%      1.188    1.699
# 75%      4.364    4.214
# max     17.958   26.039
#
# Omissions:
# omit         0        1
# count  300.000  300.000
# mean     0.832    1.092
# std      5.410    5.164
# tstat    2.665    3.662
# pval     0.008    0.000
# min    -21.567  -24.066
# 25%     -2.155   -1.746
# 50%      1.190    1.353
# 75%      4.325    4.308
# max     17.978   18.964
